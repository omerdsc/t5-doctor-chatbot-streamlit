# %%
! pip install pandas matplotlib seaborn wordcloud nltk
# Out:
# ...
#   Using cached wordcloud-1.9.4-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# ...
# Using cached wordcloud-1.9.4-cp312-cp312-win_amd64.whl (301 kB)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import nltk
import re

# 🔽 Gerekli NLTK modülleri
nltk.download("punkt")
nltk.download("stopwords")
from nltk.corpus import stopwords

# 📥 Veri setini oku
df = pd.read_csv("train_google.csv")

# 👀 İlk birkaç veriye göz at
print(df.head())

# 🧼 Boş kayıtları temizle ve tipleri düzelt
df = df.dropna(subset=["Question", "Answer"])
df["Question"] = df["Question"].astype(str).str.strip()
df["Answer"] = df["Answer"].astype(str).str.strip()

# 🧹 Türkçe stopwords listesi
stop_words = set(stopwords.words("turkish"))

# 🧠 Temizleme fonksiyonu (stopwords dahil)
def clean_text(text):
    text = text.lower()
    text = re.sub(r"http\S+|www\S+|https\S+", "", text)
    text = re.sub(r"\@\w+|\#", "", text)
    text = re.sub(r"[^\w\s]", "", text)
    tokens = text.split()
    tokens = [word for word in tokens if word not in stop_words]
    return " ".join(tokens)

# ✅ Temiz metinleri yeni sütunlara yaz
df["clean_question"] = df["Question"].apply(clean_text)
df["clean_answer"] = df["Answer"].apply(clean_text)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\omer_\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                                Title  \
# 0  Burun spreyi, sinüziti ve burun poliplerini et...
# 1  Menopoz nedir ve belirtilerini en aza indirmen...
# 2                  COVID-19 yükseltme dozları nedir?
# 3  Yoğun insanlar için uygun bir uyku programı ne...
# 4  Kasılmalı felç geçirdikten sonra kalp zayıf ol...
#
#                                             Question  \
# 0  Merhaba beyefendi, Oğlumun sinüziti ve burun p...
# 1  Orta yaşa yaklaşırken, menopozla uyumlu sempto...
# 2  Haberlerde koronavirüsün Çin, Hindistan ve diğ...
# 3  Son iki yıldır trafik polisi olarak çalışan 30...
# 4  Babamla ilgili bir sorum var. 75 yaşında, sağl...
#
#                                               Answer
# 0  Artık uzman tıbbi görüşe özel erişime sahipsin...
# 1  Sorgunuzu inceledim.  Orta yaş, bir kadının ha...
# ...

# %%
df["question_length"] = df["clean_question"].apply(lambda x: len(x.split()))
df["answer_length"] = df["clean_answer"].apply(lambda x: len(x.split()))

# 🎨 Soru Uzunluk Grafiği
sns.histplot(df["question_length"], bins=30, kde=True)
plt.title("Soru Uzunluğu Dağılımı")
plt.xlabel("Kelime Sayısı")
plt.ylabel("Sıklık")
plt.show()

# 🎨 Cevap Uzunluk Grafiği
sns.histplot(df["answer_length"], bins=30, kde=True, color="orange")
plt.title("Cevap Uzunluğu Dağılımı")
plt.xlabel("Kelime Sayısı")
plt.ylabel("Sıklık")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 17
#      15 plt.ylabel("Sıklık")
#      16 plt.show()
# ---> 17 A
#
# NameError: name 'A' is not defined

# %%
# Soru Wordcloud
text = " ".join(df["clean_question"].tolist())
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
plt.figure(figsize=(15, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Sorularda Geçen En Sık Kelimeler")
plt.show()

# Cevap Wordcloud
text = " ".join(df["clean_answer"].tolist())
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
plt.figure(figsize=(15, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Cevaplarda Geçen En Sık Kelimeler")
plt.show()

# %%
! pip install datasets

# %%
from datasets import Dataset

# Dataset objesine çevir
hf_dataset = Dataset.from_pandas(df[["clean_question", "clean_answer"]].rename(
    columns={"clean_question": "input_text", "clean_answer": "target_text"}))

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_ckpt = "google/flan-t5-base"
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
model = AutoModelForSeq2SeqLM.from_pretrained(model_ckpt)
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# C:\Users\omer_\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\omer_\.cache\huggingface\hub\models--google--flan-t5-base. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
def preprocess_function(examples):
    inputs = tokenizer(examples["input_text"], truncation=True, padding="max_length", max_length=256)
    targets = tokenizer(examples["target_text"], truncation=True, padding="max_length", max_length=256)

    inputs["labels"] = targets["input_ids"]
    return inputs

tokenized_dataset = hf_dataset.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/19583 [00:00<?, ? examples/s]

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir="./doktorbot_model",
    evaluation_strategy="no",
    per_device_train_batch_size=8,
    num_train_epochs=3,
    logging_steps=100,
    save_steps=500,
    save_total_limit=1,
    fp16=True,
    report_to="none"
)
# Out:
# WARNING:tensorflow:From C:\Users\omer_\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 from transformers import TrainingArguments, Trainer
# ----> 3 training_args = TrainingArguments(
#       4     output_dir="./doktorbot_model",
#       5     evaluation_strategy="no",
#       6     per_device_train_batch_size=8,
#       7     num_train_epochs=3,
#       8     logging_steps=100,
#       9     save_steps=500,
#      10     save_total_limit=1,
#      11     fp16=True,
#      12     report_to="none"
#      13 )
#
# TypeError: TrainingArguments.__init__() got an unexpected keyword argument 'evaluation_strategy'

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
    tokenizer=tokenizer,
)

trainer.train()

# %%
trainer.save_model("./doktorbot_model")
tokenizer.save_pretrained("./doktorbot_model")

# %%
def generate_answer(question):
    inputs = tokenizer("Soru: " + question, return_tensors="pt", truncation=True, padding=True)
    output = model.generate(**inputs, max_new_tokens=128)
    return tokenizer.decode(output[0], skip_special_tokens=True)

generate_answer("Burun spreyleri poliplere iyi gelir mi?")
